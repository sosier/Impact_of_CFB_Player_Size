# %%
import cfbd
from dotenv import load_dotenv
import json
import os
import pandas as pd

# Load environment variables from .env file
load_dotenv()

# Configure API key authorization: ApiKeyAuth
cfbd_config = cfbd.Configuration()
cfbd_config.api_key["Authorization"] = os.getenv("CFBD_API_KEY")
cfbd_config.api_key_prefix["Authorization"] = "Bearer"

teams_api = cfbd.TeamsApi(cfbd.ApiClient(cfbd_config))
games_api = cfbd.GamesApi(cfbd.ApiClient(cfbd_config))

# %%
with open("cfb_teams.json", "rb") as file:
    teams = json.load(file)

# %%
teams_df = pd.DataFrame(teams)
teams_df
# Out:
#        id             school        mascot abbreviation alt_name1 alt_name2  \
# 0    2005          Air Force       Falcons          AFA      None       AFA
# 1    2006              Akron          Zips          AKR      None       AKR
# 2     333            Alabama  Crimson Tide          ALA      None       ALA
# 3    2026  Appalachian State  Mountaineers          APP      None       APP
# 4      12            Arizona      Wildcats         ARIZ      None      ARIZ
# ..    ...                ...           ...          ...       ...       ...
# 126    98   Western Kentucky   Hilltoppers          WKU      None       WKU
# 127  2711   Western Michigan       Broncos          WMU      None       WMU
# 128   277      West Virginia  Mountaineers          WVU      None       WVU
# 129   275          Wisconsin       Badgers          WIS      None       WIS
# 130  2751            Wyoming       Cowboys          WYO      None       WYO
#
#           alt_name3      conference  division    color alt_color  \
# 0         Air Force   Mountain West  Mountain  #004a7b   #ffffff
# 1             Akron    Mid-American      East  #00285e   #84754e
# 2           Alabama             SEC      West  #690014   #f1f2f3
# 3    Appalachian St        Sun Belt      East  #000000   #ffcd00
# 4           Arizona          Pac-12      None  #002449   #00205b
# ..              ...             ...       ...      ...       ...
# 126      W Kentucky  Conference USA      None  #F32026   #b3b5b8
# 127      W Michigan    Mid-American      West  #532e1f   #8b7f79
# 128   West Virginia          Big 12      None  #FFC600   #eaaa00
# 129       Wisconsin         Big Ten      West  #A00001   #f7f7f7
# 130         Wyoming   Mountain West  Mountain  #533B22   #ffffff
#
#                                                  logos          twitter  \
# 0    [http://a.espncdn.com/i/teamlogos/ncaa/500/200...     @AF_Football
# 1    [http://a.espncdn.com/i/teamlogos/ncaa/500/200...          @ZipsFB
# 2    [http://a.espncdn.com/i/teamlogos/ncaa/500/333...     @AlabamaFTBL
# 3    [http://a.espncdn.com/i/teamlogos/ncaa/500/202...     @AppState_FB
# 4    [http://a.espncdn.com/i/teamlogos/ncaa/500/12....    @ArizonaFBall
# ..                                                 ...              ...
# 126  [http://a.espncdn.com/i/teamlogos/ncaa/500/98....     @WKUFootball
# 127  [http://a.espncdn.com/i/teamlogos/ncaa/500/271...    @WMU_Football
# 128  [http://a.espncdn.com/i/teamlogos/ncaa/500/277...     @WVUFootball
# 129  [http://a.espncdn.com/i/teamlogos/ncaa/500/275...  @BadgerFootball
# 130  [http://a.espncdn.com/i/teamlogos/ncaa/500/275...    @Wyo_Football
#
#                                               location
# 0    {'venue_id': 3713, 'name': 'Falcon Stadium', '...
# 1    {'venue_id': 3768, 'name': 'Summa Field at Inf...
# 2    {'venue_id': 3657, 'name': 'Bryant Denny Stadi...
# 3    {'venue_id': 3792, 'name': 'Kidd Brewer Stadiu...
# 4    {'venue_id': 3619, 'name': 'Arizona Stadium', ...
# ..                                                 ...
# 126  {'venue_id': 3796, 'name': 'Houchens Industrie...
# 127  {'venue_id': 3980, 'name': 'Waldo Stadium', 'c...
# 128  {'venue_id': 3842, 'name': 'Mountaineer Field ...
# 129  {'venue_id': 347, 'name': 'Camp Randall Stadiu...
# 130  {'venue_id': 3984, 'name': 'War Memorial Stadi...
#
# [131 rows x 14 columns]

# %%
fbs_teams = set(teams_df.school)
fbs_teams
# Out:
# {'Air Force',
#  'Akron',
#  'Alabama',
#  'Appalachian State',
#  'Arizona',
#  'Arizona State',
#  'Arkansas',
#  'Arkansas State',
#  'Army',
#  'Auburn',
#  'BYU',
#  'Ball State',
#  'Baylor',
#  'Boise State',
#  'Boston College',
#  'Bowling Green',
#  'Buffalo',
#  'California',
#  'Central Michigan',
#  'Charlotte',
#  'Cincinnati',
#  'Clemson',
#  'Coastal Carolina',
#  'Colorado',
#  'Colorado State',
#  'Connecticut',
#  'Duke',
#  'East Carolina',
#  'Eastern Michigan',
#  'Florida',
#  'Florida Atlantic',
#  'Florida International',
#  'Florida State',
#  'Fresno State',
#  'Georgia',
#  'Georgia Southern',
#  'Georgia State',
#  'Georgia Tech',
#  "Hawai'i",
#  'Houston',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Iowa State',
#  'James Madison',
#  'Kansas',
#  'Kansas State',
#  'Kent State',
#  'Kentucky',
#  'LSU',
#  'Liberty',
#  'Louisiana',
#  'Louisiana Monroe',
#  'Louisiana Tech',
#  'Louisville',
#  'Marshall',
#  'Maryland',
#  'Memphis',
#  'Miami',
#  'Miami (OH)',
#  'Michigan',
#  'Michigan State',
#  'Middle Tennessee',
#  'Minnesota',
#  'Mississippi State',
#  'Missouri',
#  'NC State',
#  'Navy',
#  'Nebraska',
#  'Nevada',
#  'New Mexico',
#  'New Mexico State',
#  'North Carolina',
#  'North Texas',
#  'Northern Illinois',
#  'Northwestern',
#  'Notre Dame',
#  'Ohio',
#  'Ohio State',
#  'Oklahoma',
#  'Oklahoma State',
#  'Old Dominion',
#  'Ole Miss',
#  'Oregon',
#  'Oregon State',
#  'Penn State',
#  'Pittsburgh',
#  'Purdue',
#  'Rice',
#  'Rutgers',
#  'SMU',
#  'San Diego State',
#  'San José State',
#  'South Alabama',
#  'South Carolina',
#  'South Florida',
#  'Southern Mississippi',
#  'Stanford',
#  'Syracuse',
#  'TCU',
#  'Temple',
#  'Tennessee',
#  'Texas',
#  'Texas A&M',
#  'Texas State',
#  'Texas Tech',
#  'Toledo',
#  'Troy',
#  'Tulane',
#  'Tulsa',
#  'UAB',
#  'UCF',
#  'UCLA',
#  'UMass',
#  'UNLV',
#  'USC',
#  'UT San Antonio',
#  'UTEP',
#  'Utah',
#  'Utah State',
#  'Vanderbilt',
#  'Virginia',
#  'Virginia Tech',
#  'Wake Forest',
#  'Washington',
#  'Washington State',
#  'West Virginia',
#  'Western Kentucky',
#  'Western Michigan',
#  'Wisconsin',
#  'Wyoming'}

# %%
team_records = games_api.get_team_records(year=2022)
team_records = [record.__dict__ for record in team_records]
team_records = [{**record, **record["_total"].__dict__} for record in team_records]
len(team_records)
# Out:
# 131

# %%
records_df = pd.DataFrame(team_records)

# Select relevant columns
records_df = records_df[[
    "_year",
    "_team",
    "_games",
    "_wins",
    "_losses"
]]

# Remove _ from column names
records_df = records_df.rename({col: col[1:] for col in records_df.columns}, axis=1)

records_df["win_percentage"] = records_df.wins / records_df.games

records_df
# Out:
#      year               team  games  wins  losses  win_percentage
# 0    2022          Air Force     13    10       3        0.769231
# 1    2022              Akron     13     2      10        0.153846
# 2    2022            Alabama     13    11       2        0.846154
# 3    2022  Appalachian State     12     6       6        0.500000
# 4    2022            Arizona     12     5       7        0.416667
# ..    ...                ...    ...   ...     ...             ...
# 126  2022   Western Kentucky     14     9       5        0.642857
# 127  2022   Western Michigan     12     5       7        0.416667
# 128  2022      West Virginia     12     5       7        0.416667
# 129  2022          Wisconsin     13     7       6        0.538462
# 130  2022            Wyoming     13     7       6        0.538462
#
# [131 rows x 6 columns]

# %%
roster = teams_api.get_roster(year=2022)
# Convert from Player type objects to normal dicts
roster = [player.__dict__ for player in roster]
len(roster)
# Out:
# 30420

# %%
df = pd.DataFrame(roster)

# Select relevant columns
df = df[[
    "_id",
    "_first_name",
    "_last_name",
    "_team",
    "_height",
    "_weight",
    "_position"
]]

# Remove _ from column names
df = df.rename({col: col[1:] for col in df.columns}, axis=1)

# Limit to just FBS teams:
df = df[df.team.apply(lambda team: team in fbs_teams)]

# Limit to just players with weights:
df = df[~df.weight.isnull()]

df = df.reset_index(drop=True)
df
# Out:
#             id first_name      last_name               team  height  weight  \
# 0        19014       Matt         Harmon         Kent State    77.0   254.0
# 1       102597       Will         Rogers  Mississippi State    74.0   210.0
# 2       107494       Trey        Sanders            Alabama    72.0   214.0
# 3       136429     Cedric  Patterson III               Rice    71.0   190.0
# 4       146583       John          Adams             Temple    74.0   185.0
# ...        ...        ...            ...                ...     ...     ...
# 15475  5102327       John    Yayi-Bondje              Miami    68.0   175.0
# 15476  5102330      Jacob          Fitts          Texas A&M    72.0   286.0
# 15477  5102333     Davian       Sullivan            Clemson    76.0   195.0
# 15478  5102350      Henry      Belvin IV               Duke    75.0   212.0
# 15479  5102446        Joe           Maez         New Mexico    77.0   260.0
#
#       position
# 0           LB
# 1           QB
# 2           RB
# 3           WR
# 4           WR
# ...        ...
# 15475       DB
# 15476       OL
# 15477       WR
# 15478       QB
# 15479       TE
#
# [15480 rows x 7 columns]

# %% [markdown]
# ## Save Data to CSVs

# %%
records_df.to_csv("cfb_team_records_2022.csv", index=False)
df.to_csv("cfb_players_2022.csv", index=False)
